# %%
from gtts import gTTS
import os

tts = gTTS(text="Hello World",lang="tr")
tts.save("hello.mp3")

# %%
os.system("mpg321 hello.mp3")
# Out:
# 1

# %%
#!/usr/bin/env python3
# Requires PyAudio and PySpeech.
 
import  speech_recognition as sr
from time import ctime
import time
import os
from gtts import gTTS
 
def speak(audioString):
    print(audioString)
    tts = gTTS(text=audioString, lang='tr')
    tts.save("audio.mp3")
os.system("mpg321 audio.mp3")
 
def recordAudio():
    # Record Audio
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Say something!")
        audio = r.listen(source)
 
    # Speech recognition using Google Speech Recognition
    data = ""
    try:
        # Uses the default API key
        # To use another API key: `r.recognize_google(audio, key="GOOGLE_SPEECH_RECOGNITION_API_KEY")`
        data = r.recognize_google(audio)
        print("You said: " + data)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))

    return data
 
   
def jarvis(data):
    if "how are you" in data:
        speak("I am fine")
 
    if "what time is it" in data:
        speak(ctime())
 
    if "where is" in data:
        data = data.split(" ")
        location = data[2]
        speak("Hold on Frank, I will show you where " + location + " is.")
        os.system("chromium-browser https://www.google.nl/maps/place/" + location + "/&amp;")
 
    # initialization
time.sleep(2)
speak("Hi Frank, what can I do for you?")
while 1:
    data = recordAudio()
    jarvis(data)
# Out:
# Hi Frank, what can I do for you?
# Say something!
# You said: is the weather rainy
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: what is your phone number
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: Hey Cortana
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: USB flashlight
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Could not request results from Google Speech Recognition service; recognition connection failed: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Could not request results from Google Speech Recognition service; recognition connection failed: [Errno 11001] getaddrinfo failed
# Say something!
# Could not request results from Google Speech Recognition service; recognition connection failed: [Errno 11001] getaddrinfo failed
# Say something!
# Could not request results from Google Speech Recognition service; recognition connection failed: [Errno 11001] getaddrinfo failed
# Say something!
# Could not request results from Google Speech Recognition service; recognition connection failed: [Errno 11001] getaddrinfo failed
# Say something!
# Could not request results from Google Speech Recognition service; recognition connection failed: [Errno 11001] getaddrinfo failed
# Say something!
# Could not request results from Google Speech Recognition service; recognition connection failed: [Errno 11001] getaddrinfo failed
# Say something!
# Could not request results from Google Speech Recognition service; recognition connection failed: [Errno 11001] getaddrinfo failed
# Say something!
# Could not request results from Google Speech Recognition service; recognition connection failed: [Errno 11001] getaddrinfo failed
# Say something!
# Could not request results from Google Speech Recognition service; recognition connection failed: [Errno 11001] getaddrinfo failed
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
